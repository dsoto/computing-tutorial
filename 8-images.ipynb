# %% [markdown]
# # Including images
#
# - Get your image file
# - Name it something descritive and memorable (this example uses image.png)
# - Place it in the same directory as your notebook file
# - Either
#     - Create a link in markdown using `![](image.png)`
#     - Create a link using the notebook
#
# ## This is an example using the markdown link
# ![](image.png)

# %% [markdown]
# This is an example using the code.

# %%
from IPython.display import Image
Image("image.png")
